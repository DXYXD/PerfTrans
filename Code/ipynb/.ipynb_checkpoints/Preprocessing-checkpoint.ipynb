# %% [markdown]
# 1. process the new audi and lab records <br>
# 2. Execute Perf_Trans file to get new transferings
# 3. Process new records in 7.4

# %% [markdown]
# ### Load and connect

# %%
import librosa
import librosa.display

# %%
ylab1, srlab1 = librosa.load("G:\\MusicXLab\\20190630\\011005_0193.wav", sr = None)
ylab2, srlab2  = librosa.load("G:\\MusicXLab\\20190630\\011005_0194.wav", sr = None)
yaudi1, sraudi1 = librosa.load("G:\\MusicXLab\\20190704\\011009_0196.wav", sr = None)
yaudi2, sraudi2 = librosa.load("G:\\MusicXLab\\20190704\\011009_0197.wav", sr = None)

# %%
import numpy as np

# %%
ylab = np.concatenate((ylab1, ylab2))
yaudi = np.concatenate((yaudi1, yaudi2))

# %%
sr = srlab1
threshold = 0.003
ref = 0.00002
t = 20
inter = 1.5

# %% [markdown]
# ### Compute DB

# %%
# Computing decibel by time window with length t
# Average intensity of the ﬁrst phase of decay from the peak
def compute_db(frame, t, ref):
    decibel = []
    for i in frame:
        energy = np.array(i ** 2)
        onset = np.where(energy == max(energy))[0][0] # the index of the maximum energy
        tp = np.sqrt(np.mean(energy[onset:(onset + t)])) # # root mean square amplitude of the ﬁrst 10ms after the peak
        decibel.append(librosa.amplitude_to_db([tp], ref)[0])
        
    return decibel

# %% [markdown]
# ### Compute Delay

# %%
def compute_delay(frame, threshold, sr):
    delay = []
    length = sr//100
    for i in range(4*17*88):
        j = 10
        tp = threshold+1
        while(tp > threshold):
            j+=1
            tp = np.sqrt(np.var((frame[i][j*length:j*length+length])))
        delay.append(float(j)/100)
        
    return delay

# %% [markdown]
# ### To dataframe

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import IPython

# %%
ylab0 = ylab[int(sr*61)+8800:-int(sr*31.4)]
yaudi0 = yaudi[int(sr*10.695)-200:-(sr*39)]

# %%
len(ylab0)
# Out:
# 430795424

# %%
len(yaudi0)
# Out:
# 430802552

# %%
framelab = []
frameaudi = []
for i in range(4*17*88):
    ylabi = ylab0[int(sr*1.5*i):int(sr*1.5*(i+1))]
    yaudii = yaudi0[int(sr*1.5*i):int(sr*1.5*(i+1))]
    framelab.append(ylabi)
    frameaudi.append(yaudii)
noteArraylab = np.array(framelab) 
noteArrayaudi = np.array(frameaudi)

# %%
decibel_lab = compute_db(framelab, t, ref)
decibel_audi = compute_db(frameaudi, t, ref)
delay_lab = compute_delay(framelab, threshold, sr)
delay_audi = compute_delay(frameaudi, threshold, sr)
# Out:
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3157: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# D:\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in greater
#   import sys

# %%
np.save('decibel_lab.npy', np.array(decibel_lab))
np.save('decibel_audi.npy', np.array(decibel_audi))
np.save('delay_lab.npy', np.array(delay_lab))
np.save('delay_audi.npy', np.array(delay_audi))

# %% [markdown]
# ### Info
# midi_new<br>
# 1. duration [0.1, 0.3, 0.5, 0.7]
# 2. velocity 0--127 (17 level)
# 3. notes: 88

# %%
Info = []
for n in range(21, 109):
    for v in list(range(1,127,8))+[127]:
        for d in [0.1, 0.3, 0.7, 1]:
            Info.append((n,v,d))

# %%
names = ['Info(pitch, vel, dur)', 'db(lab)', 'db(audi)', 'duration(lab)', 'duration(audi)']
data = np.array([Info, decibel_lab, decibel_audi, delay_lab, delay_audi]).T
df=pd.DataFrame(columns=names,data=data)
df.to_csv('anal_new.csv',encoding='utf-8')

# %%
list(range(1,127,8))+[127]
# Out:
# [1, 9, 17, 25, 33, 41, 49, 57, 65, 73, 81, 89, 97, 105, 113, 121, 127]

# %%
plt.figure(figsize=(8, 16))
# for i in range(10):
plt.subplot(1,2,1)
plt.plot(yaudi1[int(sr*1.5*2):int(sr*1.5*(2+1))], '|')
plt.subplot(2,2)

# %%
 plt.plot(ylab1[int(sr*1.5*200):int(sr*1.5*(200+1))], '|')

# %%
IPython.display.Audio(data=ylab1[int(sr*1.5*18):int(sr*1.5*(18+1))], rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(data=yaudi1[int(sr*1.5*17):int(sr*1.5*(17+1))], rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pretty_midi

# %%
mi = pretty_midi.PrettyMIDI('midi_file_new.midi')
mi.instruments[0].notes
