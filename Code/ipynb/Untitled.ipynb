# %%
import pretty_midi

# %%
t1 = pretty_midi.PrettyMIDI('D:\\Academic_work\\00PerfTransfer\\Song\\trial\\transP_chuange1_1.mid')
t2 = pretty_midi.PrettyMIDI('D:\\Academic_work\\00PerfTransfer\\Song\\midi_2\\chuange1.mid')

# %%
t1.instruments[0].notes
# Out:
# [Note(start=1.046875, end=2.046875, pitch=67, velocity=31),
#  Note(start=1.559375, end=2.485417, pitch=69, velocity=38),
#  Note(start=2.339583, end=5.337500, pitch=51, velocity=94),
#  Note(start=3.930208, end=5.337500, pitch=53, velocity=110),
#  Note(start=3.919792, end=5.337500, pitch=57, velocity=121),
#  Note(start=3.930208, end=5.337500, pitch=60, velocity=54),
#  Note(start=3.251042, end=5.337500, pitch=65, velocity=23),
#  Note(start=1.944792, end=5.337500, pitch=70, velocity=50),
#  Note(start=2.351042, end=5.337500, pitch=72, velocity=50),
#  Note(start=2.870833, end=5.337500, pitch=74, velocity=63),
#  Note(start=3.262500, end=5.337500, pitch=75, velocity=80),
#  Note(start=3.590625, end=5.337500, pitch=77, velocity=107),
#  Note(start=5.315625, end=5.337500, pitch=77, velocity=108),
#  Note(start=3.919792, end=5.337500, pitch=79, velocity=92),
#  Note(start=4.251042, end=5.337500, pitch=81, velocity=65),
#  Note(start=4.972917, end=5.337500, pitch=84, velocity=106),
# ...

# %%
t2.instruments[0].notes
# Out:
# [Note(start=1.046875, end=1.581250, pitch=67, velocity=45),
#  Note(start=1.559375, end=1.977083, pitch=69, velocity=51),
#  Note(start=1.944792, end=2.351042, pitch=70, velocity=69),
#  Note(start=2.339583, end=2.648958, pitch=51, velocity=57),
#  Note(start=2.351042, end=2.882292, pitch=72, velocity=74),
#  Note(start=2.870833, end=3.327083, pitch=74, velocity=78),
#  Note(start=3.262500, end=3.590625, pitch=75, velocity=80),
#  Note(start=3.590625, end=3.951042, pitch=77, velocity=78),
#  Note(start=3.919792, end=4.463542, pitch=79, velocity=88),
#  Note(start=3.251042, end=4.506250, pitch=65, velocity=70),
#  Note(start=3.930208, end=4.622917, pitch=53, velocity=70),
#  Note(start=3.930208, end=4.634375, pitch=60, velocity=72),
#  Note(start=4.251042, end=4.634375, pitch=81, velocity=88),
#  Note(start=3.919792, end=4.676042, pitch=57, velocity=70),
#  Note(start=4.581250, end=5.026042, pitch=82, velocity=88),
#  Note(start=4.972917, end=5.379167, pitch=84, velocity=85),
# ...
